# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'Cities list contains {len(cities)} cities.')
# Out:
# Cities list contains 733 cities.

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat":city_lat, 
                          "Lng":city_lng, 
                          "Max Temp":city_max_temp, 
                          "Humidity":city_humidity, 
                          "Cloudiness":city_clouds, 
                          "Wind Speed":city_wind, 
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | muros
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | avera
# Processing Record 7 of Set 1 | ranong
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | santa cruz
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | banepa
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | kotlas
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | utete
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | lobatse
# Processing Record 21 of Set 1 | villa alemana
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | yining
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | nizwa
# Processing Record 28 of Set 1 | vila praia de ancora
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | lata
# Processing Record 42 of Set 1 | champasak
# Processing Record 43 of Set 1 | roblin
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | barmer
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | wembley
# Processing Record 50 of Set 1 | komsomolskiy
# Processing Record 1 of Set 2 | northam
# Processing Record 2 of Set 2 | fairbanks
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | pacific grove
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | hovd
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | mabaruma
# Processing Record 9 of Set 2 | marzuq
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | kassala
# Processing Record 12 of Set 2 | fare
# Processing Record 13 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 2 | gold coast
# Processing Record 15 of Set 2 | praia da vitoria
# Processing Record 16 of Set 2 | ebes
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | luau
# Processing Record 19 of Set 2 | nome
# Processing Record 20 of Set 2 | burica
# City not found. Skipping...
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | alofi
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | porbandar
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | quatre cocos
# Processing Record 29 of Set 2 | havre-saint-pierre
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | labuhan
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | pochutla
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | abalak
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | makat
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | ulaanbaatar
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | coquimbo
# Processing Record 43 of Set 2 | coihaique
# Processing Record 44 of Set 2 | pontes e lacerda
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | hervey bay
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | baykit
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | honiara
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | paranaiba
# Processing Record 6 of Set 3 | goderich
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | port hedland
# Processing Record 9 of Set 3 | kirillov
# Processing Record 10 of Set 3 | kenai
# Processing Record 11 of Set 3 | san luis
# Processing Record 12 of Set 3 | chengde
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | shima
# Processing Record 17 of Set 3 | khani
# Processing Record 18 of Set 3 | shebalino
# Processing Record 19 of Set 3 | zacatlan
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | kampong thum
# Processing Record 23 of Set 3 | mehamn
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | luderitz
# Processing Record 28 of Set 3 | tucuma
# Processing Record 29 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | poum
# Processing Record 32 of Set 3 | nizhniy kuranakh
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | santa rosa
# Processing Record 35 of Set 3 | oistins
# Processing Record 36 of Set 3 | velikiy ustyug
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | skogn
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | mashhad
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | tallahassee
# Processing Record 48 of Set 3 | amahai
# Processing Record 49 of Set 3 | bougouni
# Processing Record 50 of Set 3 | hasaki
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | korla
# Processing Record 3 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 4 of Set 4 | anqing
# Processing Record 5 of Set 4 | kichmengskiy gorodok
# Processing Record 6 of Set 4 | bage
# Processing Record 7 of Set 4 | sivas
# Processing Record 8 of Set 4 | ningan
# City not found. Skipping...
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | asau
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | kargil
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | vao
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | hamilton
# Processing Record 18 of Set 4 | susanville
# Processing Record 19 of Set 4 | vostok
# Processing Record 20 of Set 4 | gunjur
# Processing Record 21 of Set 4 | tateyama
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | guiratinga
# Processing Record 25 of Set 4 | shimoda
# Processing Record 26 of Set 4 | burns lake
# Processing Record 27 of Set 4 | ust-tsilma
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | chama
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | olafsvik
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | castro
# Processing Record 36 of Set 4 | los llanos de aridane
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | tucurui
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | maniitsoq
# Processing Record 42 of Set 4 | magomeni
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | bayeux
# Processing Record 45 of Set 4 | caiaponia
# Processing Record 46 of Set 4 | yinchuan
# Processing Record 47 of Set 4 | rutul
# Processing Record 48 of Set 4 | caraballeda
# Processing Record 49 of Set 4 | georgetown
# Processing Record 50 of Set 4 | kuytun
# Processing Record 1 of Set 5 | tevriz
# Processing Record 2 of Set 5 | ahipara
# Processing Record 3 of Set 5 | shumyachi
# Processing Record 4 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | moundou
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | arilje
# Processing Record 8 of Set 5 | bom jesus da lapa
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | kaeo
# Processing Record 11 of Set 5 | deputatskiy
# Processing Record 12 of Set 5 | nishihara
# Processing Record 13 of Set 5 | maragogi
# Processing Record 14 of Set 5 | shingu
# Processing Record 15 of Set 5 | christchurch
# Processing Record 16 of Set 5 | takoradi
# Processing Record 17 of Set 5 | nam phong
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | saint andrews
# Processing Record 20 of Set 5 | ulcinj
# Processing Record 21 of Set 5 | montepuez
# Processing Record 22 of Set 5 | vestmanna
# Processing Record 23 of Set 5 | saldanha
# Processing Record 24 of Set 5 | zyryanka
# Processing Record 25 of Set 5 | kvelde
# City not found. Skipping...
# Processing Record 26 of Set 5 | trofors
# Processing Record 27 of Set 5 | cururupu
# Processing Record 28 of Set 5 | arenapolis
# Processing Record 29 of Set 5 | galesong
# Processing Record 30 of Set 5 | cherrapunji
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 5 | saint-philippe
# Processing Record 34 of Set 5 | along
# Processing Record 35 of Set 5 | kristiansund
# Processing Record 36 of Set 5 | bubaque
# Processing Record 37 of Set 5 | plettenberg bay
# Processing Record 38 of Set 5 | kita
# Processing Record 39 of Set 5 | miri
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | elmadag
# Processing Record 42 of Set 5 | karratha
# Processing Record 43 of Set 5 | mookane
# Processing Record 44 of Set 5 | zharkent
# Processing Record 45 of Set 5 | san lawrenz
# Processing Record 46 of Set 5 | tokzar
# City not found. Skipping...
# Processing Record 47 of Set 5 | yar-sale
# Processing Record 48 of Set 5 | shush
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | pandan
# Processing Record 2 of Set 6 | chara
# Processing Record 3 of Set 6 | lyambir
# Processing Record 4 of Set 6 | saint-orens-de-gameville
# Processing Record 5 of Set 6 | borama
# City not found. Skipping...
# Processing Record 6 of Set 6 | naryan-mar
# Processing Record 7 of Set 6 | sechura
# Processing Record 8 of Set 6 | necochea
# Processing Record 9 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 6 | ossora
# Processing Record 11 of Set 6 | tarauaca
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | kiunga
# Processing Record 14 of Set 6 | pontianak
# Processing Record 15 of Set 6 | paraiso
# Processing Record 16 of Set 6 | gamba
# Processing Record 17 of Set 6 | hambantota
# Processing Record 18 of Set 6 | puteyets
# Processing Record 19 of Set 6 | berdigestyakh
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | aitape
# Processing Record 22 of Set 6 | makakilo city
# Processing Record 23 of Set 6 | neiafu
# Processing Record 24 of Set 6 | simpang
# Processing Record 25 of Set 6 | henties bay
# Processing Record 26 of Set 6 | san cristobal
# Processing Record 27 of Set 6 | dong xoai
# Processing Record 28 of Set 6 | lichinga
# Processing Record 29 of Set 6 | flinders
# Processing Record 30 of Set 6 | zapolyarnyy
# Processing Record 31 of Set 6 | nsanje
# Processing Record 32 of Set 6 | roald
# Processing Record 33 of Set 6 | hudiksvall
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | moi
# Processing Record 36 of Set 6 | bendigo
# Processing Record 37 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 38 of Set 6 | banes
# Processing Record 39 of Set 6 | butaritari
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | malkara
# Processing Record 43 of Set 6 | umm lajj
# Processing Record 44 of Set 6 | ayagoz
# Processing Record 45 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | plaeng yao
# Processing Record 49 of Set 6 | zaigrayevo
# Processing Record 50 of Set 6 | bagaha
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | green river
# Processing Record 3 of Set 7 | emerald
# Processing Record 4 of Set 7 | khromtau
# Processing Record 5 of Set 7 | lakhnadon
# Processing Record 6 of Set 7 | shenzhen
# Processing Record 7 of Set 7 | clifton
# Processing Record 8 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 7 | tera
# Processing Record 10 of Set 7 | dezhou
# Processing Record 11 of Set 7 | rio gallegos
# Processing Record 12 of Set 7 | lucapa
# Processing Record 13 of Set 7 | beringovskiy
# Processing Record 14 of Set 7 | verkhoyansk
# Processing Record 15 of Set 7 | aiken
# Processing Record 16 of Set 7 | east hemet
# Processing Record 17 of Set 7 | caravelas
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | udachnyy
# Processing Record 20 of Set 7 | hami
# Processing Record 21 of Set 7 | pilar
# Processing Record 22 of Set 7 | mahibadhoo
# Processing Record 23 of Set 7 | nanae
# Processing Record 24 of Set 7 | west bay
# Processing Record 25 of Set 7 | vardo
# Processing Record 26 of Set 7 | kozan
# Processing Record 27 of Set 7 | peniche
# Processing Record 28 of Set 7 | gorom-gorom
# Processing Record 29 of Set 7 | brae
# Processing Record 30 of Set 7 | bandarbeyla
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | panzos
# Processing Record 33 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 7 | nemuro
# Processing Record 35 of Set 7 | nerchinskiy zavod
# Processing Record 36 of Set 7 | amalapuram
# Processing Record 37 of Set 7 | arbroath
# Processing Record 38 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 7 | saint-pierre
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | monsenhor gil
# Processing Record 42 of Set 7 | road town
# Processing Record 43 of Set 7 | bafq
# Processing Record 44 of Set 7 | tonekabon
# Processing Record 45 of Set 7 | bolshaya yelkhovka
# City not found. Skipping...
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | pecos
# Processing Record 49 of Set 7 | yagodnoye
# Processing Record 50 of Set 7 | morehead
# Processing Record 1 of Set 8 | sao joao da barra
# Processing Record 2 of Set 8 | fort nelson
# Processing Record 3 of Set 8 | bintulu
# Processing Record 4 of Set 8 | dawlatabad
# Processing Record 5 of Set 8 | nalut
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | madimba
# Processing Record 8 of Set 8 | cayenne
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | walcz
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 8 | wladyslawowo
# Processing Record 14 of Set 8 | cocobeach
# Processing Record 15 of Set 8 | kisangani
# Processing Record 16 of Set 8 | petrozavodsk
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | praia
# Processing Record 20 of Set 8 | morondava
# Processing Record 21 of Set 8 | veranopolis
# Processing Record 22 of Set 8 | maxixe
# Processing Record 23 of Set 8 | muroto
# Processing Record 24 of Set 8 | katobu
# Processing Record 25 of Set 8 | valley
# Processing Record 26 of Set 8 | ancud
# Processing Record 27 of Set 8 | dunedin
# Processing Record 28 of Set 8 | cubara
# Processing Record 29 of Set 8 | jalu
# Processing Record 30 of Set 8 | qaqortoq
# Processing Record 31 of Set 8 | mikumi
# Processing Record 32 of Set 8 | quimper
# Processing Record 33 of Set 8 | salalah
# Processing Record 34 of Set 8 | bambous virieux
# Processing Record 35 of Set 8 | waingapu
# Processing Record 36 of Set 8 | kupang
# Processing Record 37 of Set 8 | bayan
# Processing Record 38 of Set 8 | taltal
# Processing Record 39 of Set 8 | bowen
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | kozhevnikovo
# Processing Record 42 of Set 8 | bilibino
# Processing Record 43 of Set 8 | phillipsburg
# Processing Record 44 of Set 8 | kachug
# Processing Record 45 of Set 8 | sept-iles
# Processing Record 46 of Set 8 | manokwari
# Processing Record 47 of Set 8 | lingyuan
# Processing Record 48 of Set 8 | najran
# Processing Record 49 of Set 8 | krasnokholmskiy
# Processing Record 50 of Set 8 | batagay
# Processing Record 1 of Set 9 | guangyuan
# Processing Record 2 of Set 9 | ye
# City not found. Skipping...
# Processing Record 3 of Set 9 | bereda
# Processing Record 4 of Set 9 | ofunato
# Processing Record 5 of Set 9 | moussoro
# Processing Record 6 of Set 9 | trinidad
# Processing Record 7 of Set 9 | tchaourou
# Processing Record 8 of Set 9 | inhambane
# Processing Record 9 of Set 9 | adrar
# Processing Record 10 of Set 9 | ishigaki
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | kavieng
# Processing Record 13 of Set 9 | kavos
# Processing Record 14 of Set 9 | sosua
# Processing Record 15 of Set 9 | gulabpura
# Processing Record 16 of Set 9 | lakes entrance
# Processing Record 17 of Set 9 | pampas
# Processing Record 18 of Set 9 | marystown
# Processing Record 19 of Set 9 | chabahar
# Processing Record 20 of Set 9 | diego de almagro
# Processing Record 21 of Set 9 | khrebtovaya
# Processing Record 22 of Set 9 | scarborough
# Processing Record 23 of Set 9 | innisfail
# Processing Record 24 of Set 9 | kanigoro
# Processing Record 25 of Set 9 | bograd
# Processing Record 26 of Set 9 | manuk mangkaw
# Processing Record 27 of Set 9 | wajima
# Processing Record 28 of Set 9 | wewak
# Processing Record 29 of Set 9 | kulhudhuffushi
# Processing Record 30 of Set 9 | sitka
# Processing Record 31 of Set 9 | san carlos del zulia
# Processing Record 32 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 9 | marawi
# Processing Record 34 of Set 9 | khandyga
# Processing Record 35 of Set 9 | magadan
# Processing Record 36 of Set 9 | acuna
# City not found. Skipping...
# Processing Record 37 of Set 9 | manaus
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | shaunavon
# Processing Record 40 of Set 9 | bima
# Processing Record 41 of Set 9 | manbij
# Processing Record 42 of Set 9 | zhangzhou
# Processing Record 43 of Set 9 | torbay
# Processing Record 44 of Set 9 | biak
# Processing Record 45 of Set 9 | markdale
# Processing Record 46 of Set 9 | celestun
# Processing Record 47 of Set 9 | yulara
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | lauf
# Processing Record 50 of Set 9 | narsaq
# Processing Record 1 of Set 10 | winnemucca
# Processing Record 2 of Set 10 | mataundh
# Processing Record 3 of Set 10 | srednekolymsk
# Processing Record 4 of Set 10 | zwedru
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | uruzgan
# Processing Record 7 of Set 10 | sur
# Processing Record 8 of Set 10 | saskylakh
# Processing Record 9 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 10 | gudalur
# Processing Record 11 of Set 10 | sobolevo
# Processing Record 12 of Set 10 | walvis bay
# Processing Record 13 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 14 of Set 10 | erzin
# Processing Record 15 of Set 10 | mayo
# Processing Record 16 of Set 10 | oussouye
# Processing Record 17 of Set 10 | jutai
# Processing Record 18 of Set 10 | moerai
# Processing Record 19 of Set 10 | naica
# Processing Record 20 of Set 10 | thoen
# Processing Record 21 of Set 10 | port blair
# Processing Record 22 of Set 10 | menomonie
# Processing Record 23 of Set 10 | kristiinankaupunki
# Processing Record 24 of Set 10 | huarmey
# Processing Record 25 of Set 10 | urdoma
# Processing Record 26 of Set 10 | porangatu
# Processing Record 27 of Set 10 | stromness
# Processing Record 28 of Set 10 | fairview
# Processing Record 29 of Set 10 | simao
# Processing Record 30 of Set 10 | alma
# Processing Record 31 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 10 | padang
# Processing Record 33 of Set 10 | alice springs
# Processing Record 34 of Set 10 | saint-francois
# Processing Record 35 of Set 10 | ulladulla
# Processing Record 36 of Set 10 | honningsvag
# Processing Record 37 of Set 10 | bohumin
# Processing Record 38 of Set 10 | avila
# Processing Record 39 of Set 10 | dhidhdhoo
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | sibu
# Processing Record 42 of Set 10 | kaduqli
# Processing Record 43 of Set 10 | shiyan
# Processing Record 44 of Set 10 | guanica
# Processing Record 45 of Set 10 | beira
# Processing Record 46 of Set 10 | kalakamati
# Processing Record 47 of Set 10 | mao
# Processing Record 48 of Set 10 | rabo de peixe
# Processing Record 49 of Set 10 | port-gentil
# Processing Record 50 of Set 10 | ust-kulom
# Processing Record 1 of Set 11 | doha
# Processing Record 2 of Set 11 | heihe
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | liverpool
# Processing Record 5 of Set 11 | uyovu
# Processing Record 6 of Set 11 | ginda
# Processing Record 7 of Set 11 | broken hill
# Processing Record 8 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 11 | bartica
# Processing Record 10 of Set 11 | sakakah
# Processing Record 11 of Set 11 | broome
# Processing Record 12 of Set 11 | aldan
# Processing Record 13 of Set 11 | dickinson
# Processing Record 14 of Set 11 | hobyo
# Processing Record 15 of Set 11 | xining
# Processing Record 16 of Set 11 | mariental
# Processing Record 17 of Set 11 | pundaguitan
# Processing Record 18 of Set 11 | paamiut
# Processing Record 19 of Set 11 | chapais
# Processing Record 20 of Set 11 | san jeronimo
# Processing Record 21 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 11 | waddan
# Processing Record 23 of Set 11 | teya
# Processing Record 24 of Set 11 | sitangkai
# Processing Record 25 of Set 11 | zhigansk
# Processing Record 26 of Set 11 | angoche
# Processing Record 27 of Set 11 | huanren
# Processing Record 28 of Set 11 | dakoro
# Processing Record 29 of Set 11 | kloulklubed
# Processing Record 30 of Set 11 | bagalkot
# Processing Record 31 of Set 11 | lara
# Processing Record 32 of Set 11 | araure
# Processing Record 33 of Set 11 | smithers
# Processing Record 34 of Set 11 | jinka
# Processing Record 35 of Set 11 | monrovia
# Processing Record 36 of Set 11 | tashla
# Processing Record 37 of Set 11 | mansa
# Processing Record 38 of Set 11 | pine bluff
# Processing Record 39 of Set 11 | cortez
# Processing Record 40 of Set 11 | el carmen
# Processing Record 41 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 42 of Set 11 | mecca
# Processing Record 43 of Set 11 | bairiki
# Processing Record 44 of Set 11 | altay
# Processing Record 45 of Set 11 | bridgwater
# Processing Record 46 of Set 11 | ylojarvi
# Processing Record 47 of Set 11 | murray bridge
# Processing Record 48 of Set 11 | kovdor
# Processing Record 49 of Set 11 | isla aguada
# Processing Record 50 of Set 11 | imeni telmana
# City not found. Skipping...
# Processing Record 1 of Set 12 | cuauhtemoc
# Processing Record 2 of Set 12 | locri
# Processing Record 3 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 4 of Set 12 | ifanadiana
# Processing Record 5 of Set 12 | westerland
# Processing Record 6 of Set 12 | banjar
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 12 | zacualpa
# Processing Record 10 of Set 12 | majene
# Processing Record 11 of Set 12 | novyy urgal
# Processing Record 12 of Set 12 | rzeszow
# Processing Record 13 of Set 12 | tilichiki
# Processing Record 14 of Set 12 | polunochnoye
# Processing Record 15 of Set 12 | nagato
# Processing Record 16 of Set 12 | tonj
# Processing Record 17 of Set 12 | saryg-sep
# Processing Record 18 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 20 of Set 12 | kamaishi
# Processing Record 21 of Set 12 | rio grande
# Processing Record 22 of Set 12 | tahta
# Processing Record 23 of Set 12 | vasilsursk
# Processing Record 24 of Set 12 | margate
# Processing Record 25 of Set 12 | algiers
# Processing Record 26 of Set 12 | wellington
# Processing Record 27 of Set 12 | ixtapa
# Processing Record 28 of Set 12 | ponta delgada
# Processing Record 29 of Set 12 | prachuap khiri khan
# Processing Record 30 of Set 12 | rochegda
# Processing Record 31 of Set 12 | chivolo
# Processing Record 32 of Set 12 | yarmolyntsi
# Processing Record 33 of Set 12 | vidor
# Processing Record 34 of Set 12 | tobol
# Processing Record 35 of Set 12 | pinellas park
# Processing Record 36 of Set 12 | houston
# Processing Record 37 of Set 12 | balkanabat
# Processing Record 38 of Set 12 | yelnya
# Processing Record 39 of Set 12 | cerfontaine
# Processing Record 40 of Set 12 | otavi
# Processing Record 41 of Set 12 | sulphur
# Processing Record 42 of Set 12 | aykhal
# Processing Record 43 of Set 12 | umtata
# Processing Record 44 of Set 12 | leningradskiy
# Processing Record 45 of Set 12 | la paz
# Processing Record 46 of Set 12 | san andres
# Processing Record 47 of Set 12 | moroni
# Processing Record 48 of Set 12 | arshan
# Processing Record 49 of Set 12 | mengcheng
# Processing Record 50 of Set 12 | ugoofaaru
# Processing Record 1 of Set 13 | monroe
# Processing Record 2 of Set 13 | kyaikto
# Processing Record 3 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | wajir
# Processing Record 5 of Set 13 | grimsby
# Processing Record 6 of Set 13 | kawalu
# Processing Record 7 of Set 13 | pascagoula
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | galveston
# Processing Record 10 of Set 13 | severo-yeniseyskiy
# Processing Record 11 of Set 13 | ostrovnoy
# Processing Record 12 of Set 13 | katha
# City not found. Skipping...
# Processing Record 13 of Set 13 | ostersund
# Processing Record 14 of Set 13 | dukat
# Processing Record 15 of Set 13 | aleppo
# Processing Record 16 of Set 13 | balikpapan
# Processing Record 17 of Set 13 | caluquembe
# Processing Record 18 of Set 13 | yumen
# Processing Record 19 of Set 13 | whitehorse
# Processing Record 20 of Set 13 | garowe
# Processing Record 21 of Set 13 | wainwright
# Processing Record 22 of Set 13 | warrington
# Processing Record 23 of Set 13 | chicama
# Processing Record 24 of Set 13 | asfi
# Processing Record 25 of Set 13 | haines junction
# Processing Record 26 of Set 13 | rawah
# Processing Record 27 of Set 13 | pangnirtung
# Processing Record 28 of Set 13 | kununurra
# Processing Record 29 of Set 13 | cap malheureux
# Processing Record 30 of Set 13 | umm kaddadah
# Processing Record 31 of Set 13 | berbera
# Processing Record 32 of Set 13 | vytegra
# Processing Record 33 of Set 13 | samarai
# Processing Record 34 of Set 13 | podporozhye
# Processing Record 35 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 13 | aktash
# Processing Record 37 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 13 | mbabane
# Processing Record 39 of Set 13 | turukhansk
# Processing Record 40 of Set 13 | dinguiraye
# Processing Record 41 of Set 13 | tautira
# Processing Record 42 of Set 13 | karera
# Processing Record 43 of Set 13 | blackwater
# Processing Record 44 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 13 | gizo
# Processing Record 46 of Set 13 | ramnagar
# Processing Record 47 of Set 13 | laguna
# Processing Record 48 of Set 13 | mamallapuram
# Processing Record 49 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 13 | harper
# Processing Record 1 of Set 14 | baghdad
# Processing Record 2 of Set 14 | baft
# Processing Record 3 of Set 14 | danjiangkou
# Processing Record 4 of Set 14 | winsum
# Processing Record 5 of Set 14 | sal rei
# Processing Record 6 of Set 14 | sao gabriel da cachoeira
# Processing Record 7 of Set 14 | salinopolis
# Processing Record 8 of Set 14 | luganville
# Processing Record 9 of Set 14 | kristinehamn
# Processing Record 10 of Set 14 | ambilobe
# Processing Record 11 of Set 14 | zalantun
# Processing Record 12 of Set 14 | soure
# Processing Record 13 of Set 14 | olinda
# Processing Record 14 of Set 14 | desbiens
# Processing Record 15 of Set 14 | tamandare
# Processing Record 16 of Set 14 | riyadh
# Processing Record 17 of Set 14 | falavarjan
# Processing Record 18 of Set 14 | la ronge
# Processing Record 19 of Set 14 | skibbereen
# Processing Record 20 of Set 14 | magdalena
# Processing Record 21 of Set 14 | opuwo
# Processing Record 22 of Set 14 | pekan
# Processing Record 23 of Set 14 | lere
# Processing Record 24 of Set 14 | pechenga
# Processing Record 25 of Set 14 | parana
# Processing Record 26 of Set 14 | skegness
# Processing Record 27 of Set 14 | plaster rock
# Processing Record 28 of Set 14 | shanghai
# Processing Record 29 of Set 14 | nadym
# Processing Record 30 of Set 14 | artvin
# Processing Record 31 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 32 of Set 14 | roswell
# Processing Record 33 of Set 14 | itarema
# Processing Record 34 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 14 | lavrentiya
# Processing Record 36 of Set 14 | hokitika
# Processing Record 37 of Set 14 | chumikan
# Processing Record 38 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 14 | mitrofanovka
# Processing Record 40 of Set 14 | kazachinskoye
# Processing Record 41 of Set 14 | aripuana
# Processing Record 42 of Set 14 | mount isa
# Processing Record 43 of Set 14 | linxia
# Processing Record 44 of Set 14 | nunkini
# Processing Record 45 of Set 14 | teguldet
# Processing Record 46 of Set 14 | acapulco
# Processing Record 47 of Set 14 | sidi ali
# Processing Record 48 of Set 14 | oranjemund
# Processing Record 49 of Set 14 | weinan
# Processing Record 50 of Set 14 | vinh
# Processing Record 1 of Set 15 | mahajanga
# Processing Record 2 of Set 15 | dicabisagan
# Processing Record 3 of Set 15 | moranbah
# Processing Record 4 of Set 15 | suwannaphum
# Processing Record 5 of Set 15 | belmonte
# Processing Record 6 of Set 15 | el jicaro
# Processing Record 7 of Set 15 | xihe
# Processing Record 8 of Set 15 | zhezkazgan
# Processing Record 9 of Set 15 | ankang
# Processing Record 10 of Set 15 | onega
# Processing Record 11 of Set 15 | canutama
# Processing Record 12 of Set 15 | groningen
# Processing Record 13 of Set 15 | bafoulabe
# Processing Record 14 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 15 | melnikovo
# Processing Record 16 of Set 15 | aklavik
# Processing Record 17 of Set 15 | dalmatovo
# Processing Record 18 of Set 15 | wanning
# Processing Record 19 of Set 15 | kayankulam
# Processing Record 20 of Set 15 | cartagena
# Processing Record 21 of Set 15 | da nang
# Processing Record 22 of Set 15 | maceio
# Processing Record 23 of Set 15 | lahaina
# Processing Record 24 of Set 15 | corinto
# Processing Record 25 of Set 15 | boyabat
# Processing Record 26 of Set 15 | nago
# Processing Record 27 of Set 15 | roma
# Processing Record 28 of Set 15 | lithakia
# Processing Record 29 of Set 15 | kokkola
# Processing Record 30 of Set 15 | progreso
# Processing Record 31 of Set 15 | senmonorom
# City not found. Skipping...
# Processing Record 32 of Set 15 | aspindza
# Processing Record 33 of Set 15 | puerto colombia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Muros      ES  42.7762   -9.0603     50.09        94           0
# 1         Albany      US  42.6001  -73.9662     65.68        94         100
# 2        Qaanaaq      GL  77.4840  -69.3632     -4.25        65           0
# 3         Avarua      CK -21.2078 -159.7750     75.25        69          20
# 4          Avera      US  33.1940  -82.5271     67.51        93         100
# 5         Ranong      TH   9.9658   98.6348     76.93        88          99
# 6  Mar Del Plata      AR -38.0023  -57.5575     64.83        93          75
# 7     Santa Cruz      BO -17.8000  -63.1667     80.06        65          53
# 8   Longyearbyen      SJ  78.2186   15.6401     17.44        79           0
# 9         Banepa      NP  27.6298   85.5214     48.52        93          20
#
#    Wind Speed   Current Description
# 0        7.54             clear sky
# 1        4.00  heavy intensity rain
# 2        7.67             clear sky
# 3       11.50            few clouds
# 4       14.23       overcast clouds
# 5        3.89       overcast clouds
# 6       11.99         broken clouds
# 7        9.22         broken clouds
# 8       11.50             clear sky
# 9        2.30                  mist

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = ("WeatherPy_Database.csv")

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
