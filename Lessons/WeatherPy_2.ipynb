# %% [markdown]
# ## 6.3.1 Creating Scatterplots from data

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Read CSV file created in last lesson
# cities_csv = os.path.join("weather_data/cities.csv")
# Convert CSV to Dataframe
city_data_df = pd.read_csv("weather_data/cities.csv")

# %%
city_data_df.head(10)
# Out:
#    Unnamed: 0            City Country                 Date      Lat       Lng  \
# 0           0           Airai      TL  2022-11-07 04:57:49  -8.9266  125.4092
# 1           1         Rikitea      PF  2022-11-07 04:58:03 -23.1203 -134.9692
# 2           2  Saint-Philippe      RE  2022-11-07 04:58:04 -21.3585   55.7679
# 3           3         Qaanaaq      GL  2022-11-07 04:58:04  77.4840  -69.3632
# 4           4         Husavik      IS  2022-11-07 04:57:18  66.0449  -17.3389
# 5           5            Boma      GH  2022-11-07 04:58:05   7.0805   -2.1697
# 6           6      Nanortalik      GL  2022-11-07 04:58:05  60.1432  -45.2371
# 7           7            Roma      US  2022-11-07 04:58:05  43.2128  -75.4557
# 8           8            Lebu      CL  2022-11-07 04:58:06 -37.6167  -73.6500
# 9           9       Jamestown      US  2022-11-07 04:58:06  42.0970  -79.2353
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     75.43        54         100        2.01
# ...

# %%
# Extract relevant fields from dataframe for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %% [markdown]
# ### Switch to API_Practice to practice time module

# %%
# Scatterplot for latitude vs max temp
import time # to get dates

plt.scatter(lats, max_temps, 
            edgecolor='black', linewidths=1, marker='o', 
            alpha=0.8, label='Cities')

plt.title(f'City Latitude Vs. Max Temperature {time.strftime("%x")}')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save figure
plt.savefig("weather_data/Fig1.png")

plt.show()

# %% [markdown]
# ## 6.3.2 Repurpose code for humidity

# %%
# Humidity
plt.scatter(lats, humidity, 
            edgecolor='black', linewidths=1, marker='o', 
            alpha=0.8, label='Cities')

plt.title(f'City Latitude Vs. Humidity {time.strftime("%x")}')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save figure
plt.savefig("weather_data/Fig2.png")

plt.show()

# %% [markdown]
# ## 6.3.3 Cloudiness

# %%
plt.scatter(lats, cloudiness, 
            edgecolor='black', linewidths=1, marker='o', 
            alpha=0.8, label='Cities')

plt.title(f'City Latitude Vs. Cloudiness {time.strftime("%x")}')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save figure
plt.savefig("weather_data/Fig3.png")

plt.show()

# %% [markdown]
# ## 6.3.4 Wind Speed

# %%
plt.scatter(lats, wind_speed, 
            edgecolor='black', linewidths=1, marker='o', 
            alpha=0.8, label='Cities')

plt.title(f'City Latitude Vs. Wind Speed {time.strftime("%x")}')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save figure
plt.savefig("weather_data/Fig4.png")

plt.show()

# %% [markdown]
# ## 6.4.2 Use function to repeat linear regressions

# %%
from scipy.stats import linregress

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate regression line y-values from slope and intercept
    regress_values = x_values * slope + intercept
    # Create a string for line equation
    line_eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
    
    # Create scatter plot with regression line"
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'red')
    
    # Annotation and labels
    plt.annotate(line_eq, text_coordinates, fontsize=15, color='r')
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    
    plt.show()

# %%
city_data_df = city_data_df.rename(columns={"Unnamed: 0":"City_ID"})

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City_ID                        13
# City                    Tuatapere
# Country                        NZ
# Date          2022-11-07 04:58:44
# Lat                      -46.1333
# Lng                      167.6833
# Max Temp                     55.4
# Humidity                       78
# Cloudiness                     93
# Wind Speed                   5.21
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 573     True
# 574     True
# 575     True
# 576     True
# 577     True
# Name: Lat, Length: 578, dtype: bool

# %%
city_data_df.loc[city_data_df["Lat"] >= 0].head()
# Out:
#    City_ID        City Country                 Date      Lat      Lng  \
# 3        3     Qaanaaq      GL  2022-11-07 04:58:04  77.4840 -69.3632
# 4        4     Husavik      IS  2022-11-07 04:57:18  66.0449 -17.3389
# 5        5        Boma      GH  2022-11-07 04:58:05   7.0805  -2.1697
# 6        6  Nanortalik      GL  2022-11-07 04:58:05  60.1432 -45.2371
# 7        7        Roma      US  2022-11-07 04:58:05  43.2128 -75.4557
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 3     -3.08        85         100        9.13
# 4     38.66        98         100        2.19
# 5     69.78        99          54        1.83
# 6     30.78        83          79        5.17
# 7     65.73        93         100        4.61

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# %%
# Call the plot_linear_regression function after assigning values
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call function
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for Maximum Temperature", 
                       "Max Temp", (5, -10))

# %%
# Smae thing for Southern hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Southern Hemisphere \n for Maximum Temperature", 
                        "Max Temp", (-55,95))

# %% [markdown]
# ## 6.4.3

# %% [markdown]
# ### Now that we have Northern and Southern Hemisphere dataframes and a function to create a scatter plot with a linear regression line and formula, we can use a similar process to the one above to plot other types of relationships

# %%
# Plot Latitude vs. Humidity

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Norhtern Hemisphere \n for % Humidity",
                       "%Humidity", (42, 15))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Southern Hemisphere \n for % Humidity", 
                       "% Humidity", (-57, 17))

# %% [markdown]
# ## 6.4.4 Cloudiness

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plot_linear_regression(x_values, y_values, "Linear Regression for the Northern Hemispher \n for % Cloudiness", 
                       "% Cloudiness", (10, 45))

print(linregress(x_values, y_values))
# Out:
# LinregressResult(slope=0.36098018426010775, intercept=47.473709260141305, rvalue=0.1817582046174966, pvalue=0.00024008471956009817, stderr=0.0974050456710377, intercept_stderr=4.192725746632538)

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plot_linear_regression(x_values, y_values, "Linear Regression for the Southern Hemispher \n for % Cloudiness", 
                       "% Cloudiness", (-57, 9))

print(linregress(x_values, y_values))
# Out:
# LinregressResult(slope=0.5322282737014872, intercept=73.02060886398057, rvalue=0.20394826106518116, pvalue=0.006948489982354393, stderr=0.19479969446703513, intercept_stderr=5.056195615635747)

# %%
# rvalues shows correlation

# %% [markdown]
# ## 6.4.5 Wind Speed

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plot_linear_regression(x_values, y_values, "Linear Regression for the Northern Hemispher \n for Wind Speed", 
                       "Wind Speed", (0, 26))

print(linregress(x_values, y_values))
# Out:
# LinregressResult(slope=0.060932768893268825, intercept=4.76123185215528, rvalue=0.2308062620945011, pvalue=2.7558717935796964e-06, stderr=0.01281158959424527, intercept_stderr=0.5514650825019155)

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plot_linear_regression(x_values, y_values, "Linear Regression for the Southern Hemispher \n for Wind Speed", 
                       "Wind Speed", (-23, 16))

print(linregress(x_values, y_values))
# Out:
# LinregressResult(slope=-0.07447911805991417, intercept=5.789678884139407, rvalue=-0.19724926746469967, pvalue=0.009085375798061067, stderr=0.028225233805992286, intercept_stderr=0.7326105095318949)
